# %%
from langchain.llms import OpenAI
import os

# %%
myllm = OpenAI(
    model = 'text-davinci-003',
    temperature=1,
    openai_api_key=key
)

# %%
os.environ['OPENAI_API_KEY'] = key

# %%
from langchain.agents import load_tools
from langchain.agents import initialize_agent

tools = load_tools(['dalle-image-generator'])

agent = initialize_agent(tools, llm =myllm, agent="zero-shot-react-description", verbose=True)

# %%
output = agent.run("Create an image of boy playing cricket in morning and return the url from observation")
# Out:
# > Entering new AgentExecutor chain...
#  Text description of a boy playing cricket in morning is provided
# Action: Dall-E Image Generator
# Action Input: A boy playing cricket in morning
# Observation: https://oaidalleapiprodscus.blob.core.windows.net/private/org-c9YdrqsWbmw5iyDOktS0ONfX/user-7zs1uI5keVHcVUDFUdd53uk4/img-65cARXsHznYhuPLZpA0kAtNu.png?st=2023-08-18T11%3A46%3A34Z&se=2023-08-18T13%3A46%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-08-17T17%3A58%3A16Z&ske=2023-08-18T17%3A58%3A16Z&sks=b&skv=2021-08-06&sig=YjJseZbllSf7mIOypzDUhdfIDAI2zrqwJ7dmfBasUlg%3D
# Thought: This image has been generated
# Final Answer: https://oaidalleapiprodscus.blob.core.windows.net/private/org-c9YdrqsWbmw5iyDOktS0ONfX/user-7zs1uI5keVHcVUDFUdd53uk4/img-65cARXsHznYhuPLZpA0kAtNu.png?st=2023-08-18T11%3A46%3A34Z&se=2023-08-18T13%3A46%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-08-17T17%3A58%3A16Z&ske=2023-08-18T17%
#
# > Finished chain.

# %%
output
# Out:
# 'The generated image url is https://oaidalleapiprodscus.blob.core.windows.net/private/org-c9YdrqsWbmw5iyDOktS0ONfX/user-7zs1uI5keVHcVUDFUdd53uk4/img-qjBdOlQDxj5nOMlH8mVlj9Db.png?st=2023-08-12T14%3A06%3A30Z&se=2023-08-12T16%3A06%3A30Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6ea-484e-a814-9c849652bcb3&skt=2023-08-11T17:19:30Z&ske=2023-08'
