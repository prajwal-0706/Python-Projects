# %%
import tkinter as tk
import os
from PIL import ImageTk

# %%
def on_button_click_1():
    result_label.config(text="Opening the Notepad")
    os.system("notepad")
    
def on_button_click_2():
    result_label.config(text="Opening the Notepad")
    os.system("start iexplore")
    
def on_button_click_3():
    result_label.config(text="Opening the Calculator")
    os.system("calc")
    
def on_button_click_4():
    result_label.config(text="Opening the VS Code")
    os.system("code .")
        
def main():
    global root, result_label

    root = tk.Tk()
    root.title("Menu of Team 10")
    root.minsize(700,700)
    
    img = ImageTk.PhotoImage(file='image.jpg', master= root)
    img_label= tk.Label(root,image=img)
    img_label.place(x = 0, y = 0)

    label = tk.Label(root, text="Menu", font= ("Arial", 20))
    label.grid(row = 0, column = 0, sticky = tk.W,  pady = 10)
    
    button_style_1 = {
        "font": ("Arial", 12),
        "bg": "#4CAF50",  
        "fg": "white",    
        "bd": 2,         
    }
    
    button_style_2 = {
        "font": ("Arial", 12),
        "bg": "#219EBC",  
        "fg": "white",    
        "bd": 2,         
    }
    
    button_style_3 = {
        "font": ("Arial", 12),
        "bg": "#fb8500",  
        "fg": "white",    
        "bd": 2,         
    }
    
    button_style_4 = {
        "font": ("Arial", 12),
        "bg": "#eaac8b",  
        "fg": "white",    
        "bd": 2,         
    }
    

    button = tk.Button(root, text="Open the Notepad", command=on_button_click_1,**button_style_1)
    button.grid(row = 1, column = 0, pady = 10, padx = 20)
    
    button1 = tk.Button(root, text="Open the explorer", command=on_button_click_2, **button_style_2)
    button1.grid(row = 1, column = 1, pady = 10)
    
    button2 = tk.Button(root, text="Open the Calculator", command=on_button_click_3, **button_style_3)
    button2.grid(row = 2, column = 0, pady = 10)
    
    button3 = tk.Button(root, text="Open the VS Code", command=on_button_click_4, **button_style_4)
    button3.grid(row = 2, column = 1, pady = 10, padx = 20)

    result_label = tk.Label(root, text="", fg="red")
    result_label.grid(row = 0, column = 0, pady = 10)

    root.mainloop()


main()

# %%
root = tk.Tk()
root.title("Menu of Team 10")
root.minsize(700,700)

label = tk.Label(root, text="Menu", font= ("Arial", 20))
label.grid(row = 0, column = 0, pady = 20 )

root.mainloop()

# %%
root = tk.Tk()
root.title("Creative Voice Recognition System")

# Background color and window size
root.configure(bg="lightblue")
root.geometry("4000x2500")
# Button with gradient color to trigger voice recognition
button = tk.Button(root, text="Listen And Recognize", font=("Arial", 20),
                   fg="white", bg="#008080", activebackground="#00a3a3", relief="raised")
button.grid(row=2, column=18, columnspan=2, pady=20)
#button-2
button = tk.Button(root, text="Launch Ec2 Instance", font=("Arial", 20),
                   fg="white", bg="#008080", activebackground="#00a3a3", relief="raised")
button.grid(row=3, column=18, columnspan=2, pady=20)
# Label to display messages with a colorful background
label = tk.Label(root, text="Hello! GOOD MORNING", font=("Arial", 16, "bold"), fg="white", bg="purple")
label.grid(row=0, column=18, columnspan=2, pady=20)




# Emoji image to add creativity

# emoji_img = tk.PhotoImage(file="pngegg.png")  # Replace with the path to your emoji image
# sub_smaple=2
# small_image=emoji_img.subsample(sub_smaple,sub_smaple)
# emoji_label = tk.Label(root, image=emoji_img, bg="lightblue")
# emoji_label.grid(row=5, column=10, columnspan=2, pady=10)

emoji_img = ImageTk.PhotoImage(file='image.png', master= root)  # Replace with the path to your emoji image
subsample_factor = 5  # Adjust this value to control the size of the image (higher value for smaller size)
# small_image = emoji_img.subsample(subsample_factor, subsample_factor)
emoji_label = tk.Label(root, image=emoji_img, bg="black")
emoji_label.grid(row=3, column=12, columnspan=2, pady=10)


# Customized message with color and font
#custom_message = tk.Label(root, text="Let your voice be heard!", font=("Arial", 15, "italic"), fg="blue", bg="lightblue")
#custom_message.grid(row=3, column=0, columnspan=2, pady=5)


# Run the main loop
root.mainloop()
